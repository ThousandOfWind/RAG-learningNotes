# %% [markdown]
# # Query Optimization
# Compare on Raw Query, Sub-Query, and HyDE Query
# * Sub-Query could possible to fetch more information, especially for Comparison and Summary Task. 😄
# * HyDE Query will miss stories which are completely beyond LLM imagination. 😅

# %%
import nest_asyncio

nest_asyncio.apply()

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from llama_index.core.tools import QueryEngineTool, ToolMetadata
from llama_index.core.query_engine import SubQuestionQueryEngine
from llama_index.core.callbacks import CallbackManager, LlamaDebugHandler
from llama_index.core import Settings
# Using the LlamaDebugHandler to print the trace of the sub questions
# captured by the SUB_QUESTION callback event type
llama_debug = LlamaDebugHandler(print_trace_on_end=False)
callback_manager = CallbackManager([llama_debug])

Settings.callback_manager = callback_manager

from azureresource import (
    get_llm,
    get_embed_model,
    get_vector_store
)
from index import build_index, get_index
llm = get_llm("gpt-35-turbo", "gpt-35-turbo-1106")
embed_model = get_embed_model("text-embedding-ada-002", "text-embedding-ada-002")
vector_store = get_vector_store("chunk-512")

Settings.llm = llm
Settings.embed_model = embed_model
index = get_index(vector_store, llm, embed_model)

# %%
# setup base query engine as tool
query_engine_tools = [
    QueryEngineTool(
        query_engine=index.as_query_engine(),
        metadata=ToolMetadata(
            name="SpainTravelEssay",
            description="本书记述了作者在西班牙旅行的经历。面对西班牙既充满异域风情而又绚丽多姿的历史、艺术、人物和宫殿、教堂、城堡等文化精华，作者在描述其无与伦比的人文及艺术价值外，更把上千年来发生在这块土地上的故事，糅进漫游的行程，使帝王将相、战火烽烟、山川景物，尤其是它走向现代国家的进程贯穿于全书，不但能让读者领略西班牙迷人的风貌，更能深入西班牙幽深的历史，洞悉它深刻而富于启示的社会演化过程。",
        ),
    ),
]

sub_query_engine = SubQuestionQueryEngine.from_defaults(
    query_engine_tools=query_engine_tools,
    use_async=True,
)

# %%
from testcase import question_list, bcolors
for q in question_list:
    print(f"{bcolors.BOLD}{bcolors.HEADER}Q: {q}{bcolors.ENDC}")
    results = sub_query_engine.query(q)
    print("response", results.response)
    for node in results.source_nodes:
        print(node)
# Out:
# Q: 在巴塞罗那可以体验哪些有趣的事情
# Generated 2 sub questions.
# [SpainTravelEssay] Q: What are the historical landmarks in Barcelona?
# [SpainTravelEssay] Q: What are the cultural attractions in Barcelona?
# [SpainTravelEssay] A: The cultural attractions in Barcelona include the Montjuic mountain, which hosted the 1929 World Expo, offering panoramic views of the city and the Mediterranean Sea. Additionally, the coastal town of Sitges, known for its nine beautiful beaches and a 17th-century church, provides a charming old town with narrow stone streets and traditional architecture.
# [SpainTravelEssay] A: The historical landmarks in Barcelona include Montjuic Mountain, which hosted the 1929 World Exposition, offering panoramic views of the city and the Mediterranean Sea. Another notable landmark is the monument to Cervantes in the expanded new city area.
# response 您可以在巴塞罗那体验登上蒙特惠奇山，欣赏城市和地中海的全景，还可以前往西特格斯的海滨小镇，探索其美丽的海滩和迷人的老城区。
# Node ID: 18a1b5aa-dca9-48ad-9110-bba852870f59
# Text: Sub question: What are the historical landmarks in Barcelona?
# Response: The historical landmarks in Barcelona include Montjuic
# Mountain, which hosted the 1929 World Exposition, offering panoramic
# views of the city and the Mediterranean Sea. Another notable landmark
# is the monument to Cervantes in the expanded new city area.
# Score: None
#
# Node ID: 994bcdf0-11fe-441b-95c8-b38bf83232ce
# Text: Sub question: What are the cultural attractions in Barcelona?
# Response: The cultural attractions in Barcelona include the Montjuic
# mountain, which hosted the 1929 World Expo, offering panoramic views
# of the city and the Mediterranean Sea. Additionally, the coastal town
# of Sitges, known for its nine beautiful beaches and a 17th-century
# church, pr...
# Score: None
#
# Node ID: d7d9ef86-485f-45b4-b11a-d1b46dc85e5f
# Text: 几乎在佛朗哥1975年年底去世的瞬间，人们就知道了，西班牙将要迅速变革。于是，我们仍然想知道，在佛朗哥统治时期，究竟为这样的变革
# ，做了一些什么准备。将近半个世纪西班牙人是怎么走过来的。他们后来的政治改革相对顺利，恐怕不能说和前面的路程毫无关系。  在巴塞罗那，我一直很
# 喜欢世界博览会的那一片叫做蒙特惠奇山（Montjuic）的地方。那是巴塞罗那市里的一座山，在此曾经举办了1929年世界博览会，可以居高临下俯
# 视巴塞罗那海港和蓝得叫人晕眩的地中海。那里唯一煞风景的是：为制造卖点，巴塞罗那人建造了一个虚假的西班牙“村庄”（Pole
# Espanyol），卖着很贵的门票，里面是很拙劣的假货。只要不进这个“假村庄”，蒙特惠奇绝对是一个很值得去的地方。
# ![image](../Images/194....
# Score:  0.843
#
# Node ID: 8b12c207-b98b-425e-a4bc-e19fc6bdd1c6
# Text: ![image](../Images/111.jpeg)  在街头描画菜单的西班牙老人  马约尔广场和老市政广场所在的这一片，就
# 是这个城市的老城区。可惜我们没有时间能像在巴塞罗那一样，好好在马德里的老城区逛逛。在马德里扩建的新城区，也有一些很好玩的地方。例如塞万提斯的
# 纪念碑。  在十六七世纪的风云跌宕起伏中，难得有一个平民，活得像塞万提斯那样，堪称是整整一本西班牙的二百年传奇。他在西班牙游历过，也阅读过和
# 思想过；他高谈阔论，又出国打仗，着实冲锋陷阵、流血受伤，受到皇家嘉奖；他当过海盗的人质奴隶，又逃跑被抓，差点上绞架在海外死个不明不白；等他终
# 于回到故乡，必须吃吃力力地谋生，却又蒙冤入狱。最后重病一场，死在家中。甚至没有人知道他的长相。可是他用笔塑造的两个人物，却永久地站在马德里的
# 市中心...
# Score:  0.840
#
# Node ID: d7d9ef86-485f-45b4-b11a-d1b46dc85e5f
# Text: 几乎在佛朗哥1975年年底去世的瞬间，人们就知道了，西班牙将要迅速变革。于是，我们仍然想知道，在佛朗哥统治时期，究竟为这样的变革
# ，做了一些什么准备。将近半个世纪西班牙人是怎么走过来的。他们后来的政治改革相对顺利，恐怕不能说和前面的路程毫无关系。  在巴塞罗那，我一直很
# 喜欢世界博览会的那一片叫做蒙特惠奇山（Montjuic）的地方。那是巴塞罗那市里的一座山，在此曾经举办了1929年世界博览会，可以居高临下俯
# 视巴塞罗那海港和蓝得叫人晕眩的地中海。那里唯一煞风景的是：为制造卖点，巴塞罗那人建造了一个虚假的西班牙“村庄”（Pole
# Espanyol），卖着很贵的门票，里面是很拙劣的假货。只要不进这个“假村庄”，蒙特惠奇绝对是一个很值得去的地方。
# ![image](../Images/194....
# Score:  0.834
#
# Node ID: e2c89747-796c-4772-b4ed-839e4a904e35
# Text: ![image](../Images/221.jpeg)  海滨小城西格斯
# 就在那顿难忘的午饭之后，我们去了西格斯，见识了巴塞罗那附近的海滩。西格斯有九个美丽的滨海沙滩。高高的山崖上一个十七世纪的大教堂（Sant
# Bartomeui Santa Tecla）更是一下就给西格斯提了神。令人流连忘返的，是教堂后面的老城，窄窄的石头小街，连片的民居，孩子们在
# 那里嬉戏。整个街区都是用老石头垒出来，每一个门，每一个窗，每一个转角，都是美的。我们巧遇一群西班牙少年鼓手，多半还是女孩儿。他们穿着明朗的色
# 彩，一色斜挎着两端镶红边的湛蓝色洋鼓，行走在青石黄石浅咖啡色木门的古旧街道，把古老的西班牙点缀得生机勃勃。他们打着鼓点，奏响流行音乐，他们是
# 今天西班牙的主人。看到这一幕，也会想到老一代人的局限在哪里...
# Score:  0.833
#
# Q: 阿尔罕宫的有趣历史故事
# Generated 1 sub questions.
# [SpainTravelEssay] Q: What is the history of Alhambra Palace?
# [SpainTravelEssay] A: The history of Alhambra Palace involves its significance to the Spanish people and its preservation efforts. It was a place of interest for Washington Irving, who played a role in drawing attention to its cultural and historical value. The palace was originally built during the Moorish rule and later came under the rule of Fernando III, who maintained a relatively mild governance and honored his promises to the Islamic kingdom of Granada. Today, the palace is a popular tourist attraction and continues to be preserved for its historical and architectural significance.
# response 阿尔罕宫的历史充满了文化和历史价值，它最初是在摩尔人统治时期建造的，后来又被费尔南多三世统治。如今，这座宫殿因其历史和建筑意义而备受游客青睐，并且一直在进行保护工作。
# Node ID: 7a66faa5-9df6-489e-9c14-be73035f7cdb
# Text: Sub question: What is the history of Alhambra Palace? Response:
# The history of Alhambra Palace involves its significance to the
# Spanish people and its preservation efforts. It was a place of
# interest for Washington Irving, who played a role in drawing attention
# to its cultural and historical value. The palace was originally built
# during the Moor...
# Score: None
#
# Node ID: d2810339-1899-4850-af0f-cd22c2bbc2a4
# Text: 它日日在衰败和坍塌。华盛顿·欧文写的《阿尔汉布拉的故事》，如同是为西班牙人拂去了一件熟视无睹的旧物上的尘埃，让他们看到金子的光泽
# 。西班牙人这才开始着手修缮和保护，阿尔汉布拉宫才有了今天的景象。  华盛顿·欧文自己说，1829年春天，他是被“好奇”带到了西班牙。也因此有
# 了这次从塞维利亚到格拉那达的旅行。同行的有他趣味相投的俄国朋友，驻马德里俄国使馆的一名官员。如今我们是顺着现代公路坐汽车来的，而在华盛顿·欧
# 文的时代，这段由骡子主导的旅途，与其说是旅行不如说是探险。山区强盗出没，旅人骡帮都必须成帮结伙，“武装到牙齿”。他最终抵达格拉那达的时候，当
# 然还没有这个“美国旅馆”。可是他真是幸运，一个还相当完整的阿尔汉布拉宫，在默默地等待着他。
# 华盛顿·欧文踏上格拉那达的心情，和我们不可能是一样的...
# Score:  0.859
#
# Node ID: e11bace0-6696-46aa-84d0-6a5c77887838
# Text: ![image](../Images/079.jpeg)  王宫庭院  我们不知道。
# 我们知道的是，根据历史记载，费尔南多三世本人在征服之后，统治还算是温和的，也信守他对格拉那达这样的伊斯兰小王国的诺言。  塞维利亚主教堂对面
# ，是费尔南多三世曾经住过的摩尔人留下的王宫。那是非常美丽的一个阿拉伯王宫。我们那天是双重幸运。先是在那个庭院的楼梯口，偶然地遇上在卖王宫楼上
# 的参观票。后来才知道，每天只有上午开放，一共也就放进去几批人，每批十个。幸而我们眼疾手快，稀里糊涂地买了下来——这已经是当天的最后两张票了。
# 上得楼去，发现带领我们的女士能够说英语，从她口中这才知道我们撞上了第二个幸运。原来这是一座“活”的王宫。我们参观的第二天，西班牙国王胡安·卡
# 洛斯一世要来塞维利亚大学，“驾临”一个仪式...
# Score:  0.855
#
# Q: 塞维利亚有哪些美食
# Generated 1 sub questions.
# [SpainTravelEssay] Q: What are the traditional dishes of Seville?
# [SpainTravelEssay] A: Seville is known for its traditional dishes such as gazpacho, salmorejo, and pescaíto frito (fried fish). These dishes are popular in the region and are often enjoyed by locals and visitors alike.
# response Seville is known for its traditional dishes such as gazpacho, salmorejo, and pescaíto frito (fried fish). These dishes are popular in the region and are often enjoyed by locals and visitors alike.
# Node ID: 7c30b71f-0f66-42be-9205-81487330a031
# Text: Sub question: What are the traditional dishes of Seville?
# Response: Seville is known for its traditional dishes such as
# gazpacho, salmorejo, and pescaíto frito (fried fish). These dishes are
# popular in the region and are often enjoyed by locals and visitors
# alike.
# Score: None
#
# Node ID: 4849dac6-9084-4a3e-9441-54f5631c266e
# Text:
# 西班牙人的晚饭时间常常在晚上十点、十一点。记得住在塞维利亚的小旅馆里，我们准备睡觉的时候，下面厨房里的锅碗瓢勺就叮叮当当地准时响起来。  !
# Score:  0.826
#
# Node ID: 8b12c207-b98b-425e-a4bc-e19fc6bdd1c6
# Text: ![image](../Images/111.jpeg)  在街头描画菜单的西班牙老人  马约尔广场和老市政广场所在的这一片，就
# 是这个城市的老城区。可惜我们没有时间能像在巴塞罗那一样，好好在马德里的老城区逛逛。在马德里扩建的新城区，也有一些很好玩的地方。例如塞万提斯的
# 纪念碑。  在十六七世纪的风云跌宕起伏中，难得有一个平民，活得像塞万提斯那样，堪称是整整一本西班牙的二百年传奇。他在西班牙游历过，也阅读过和
# 思想过；他高谈阔论，又出国打仗，着实冲锋陷阵、流血受伤，受到皇家嘉奖；他当过海盗的人质奴隶，又逃跑被抓，差点上绞架在海外死个不明不白；等他终
# 于回到故乡，必须吃吃力力地谋生，却又蒙冤入狱。最后重病一场，死在家中。甚至没有人知道他的长相。可是他用笔塑造的两个人物，却永久地站在马德里的
# 市中心...
# Score:  0.822
#
# Q: 如何准备一次西班牙旅行
# Generated 3 sub questions.
# [SpainTravelEssay] Q: What are the historical landmarks in Spain?
# [SpainTravelEssay] Q: What is the cultural heritage of Spain?
# [SpainTravelEssay] Q: What are the popular tourist attractions in Spain?
# [SpainTravelEssay] A: Popular tourist attractions in Spain include the city of Barcelona, known for its historic architecture and proximity to the Mediterranean Sea, as well as the capital city of Madrid, which is rich in history and surrounded by ancient towns. Additionally, regions like Catalonia and the Basque Country are known for their strong sense of independence and prosperity, making them attractive destinations for tourists.
# [SpainTravelEssay] A: The cultural heritage of Spain includes its rich history of colonialism, the influence of Catholicism, and the tradition of religious processions and celebrations. Additionally, Spain's cultural heritage is reflected in its unique landscapes, such as the mountains and the significance of saints in local traditions.
# [SpainTravelEssay] A: The historical landmarks in Spain include the Alhambra, ancient castles and fortresses, medieval churches, and remnants of the Spanish Inquisition. These landmarks reflect the country's rich and diverse history, from the medieval period to the Spanish Civil War.
# response You can prepare for a trip to Spain by researching and planning visits to historical landmarks such as the Alhambra, ancient castles, fortresses, and medieval churches. Additionally, consider exploring the cultural heritage by learning about Spain's history of colonialism, the influence of Catholicism, and the tradition of religious processions and celebrations. Popular tourist attractions like Barcelona, Madrid, Catalonia, and the Basque Country are also worth considering for your itinerary.
# Node ID: c3417f56-4236-412d-8336-346d5ababa56
# Text: Sub question: What are the historical landmarks in Spain?
# Response: The historical landmarks in Spain include the Alhambra,
# ancient castles and fortresses, medieval churches, and remnants of the
# Spanish Inquisition. These landmarks reflect the country's rich and
# diverse history, from the medieval period to the Spanish Civil War.
# Score: None
#
# Node ID: 1be449e2-84f9-4dfe-9e4d-ec6be92156f2
# Text: Sub question: What is the cultural heritage of Spain? Response:
# The cultural heritage of Spain includes its rich history of
# colonialism, the influence of Catholicism, and the tradition of
# religious processions and celebrations. Additionally, Spain's cultural
# heritage is reflected in its unique landscapes, such as the mountains
# and the significan...
# Score: None
#
# Node ID: fab017be-f156-4671-85c1-28e66a2417c1
# Text: Sub question: What are the popular tourist attractions in Spain?
# Response: Popular tourist attractions in Spain include the city of
# Barcelona, known for its historic architecture and proximity to the
# Mediterranean Sea, as well as the capital city of Madrid, which is
# rich in history and surrounded by ancient towns. Additionally, regions
# like Cata...
# Score: None
#
# Node ID: 2bc53264-299c-4966-ba43-3967bf9e1e77
# Text: Putnam’s Sons, New York, 1949  _Tales of the Alhambra_ ,
# Washington Irving, Club Everest, 1977  _Spain_ , _The Root and the
# Flower_ , John A. Crow，University of California Press, 1985  _The
# Spanish Republic and The Civil War, 1931-1939_ , Gabriel Jackson,
# Princeton University Press, 1972  _Spain_ , _Dictatorship to
# Democracy_ , Raymond Carr and ...
# Score:  0.850
#
# Node ID: a4bfec6e-994d-4372-835d-146131e9497c
# Text: 教堂后面，还有一个非常耐看的十字架纪念石柱。我喜欢这里，是因为每一个细节，都是用过心的。
# 孤堡成为遗迹，它的灵魂不死。谁能相信，这个教堂还在使用中。大门上嵌着装饰精美的小瞭望孔，就在它旁边，一张小小的浅黄纸片，写着每周弥撒的时间。
# 这就是古老的西班牙，延续着中世纪的加泰罗尼亚。  在西班牙旅行，常常有这样的孤独身影在远处掠过，那就是山顶上巍峨的城堡。城堡独特的造型，端端
# 正正地落在山巅，衬着蓝天背景，像《堂·吉诃德》里的一幅版画插图。我们一开始看到这样的山巅孤堡从火车的窗外一掠而过，总是赶紧查看地名，试图从旅
# 行指南中找到一点蛛丝马迹，期盼着将来能上去看看。后来发现，大多此类遗迹都并不载入书中。因为实在太多了。
# 西班牙在历史漫长的岁月里，始终是分散的。这是一个多山的国家，交通不便，贵...
# Score:  0.846
#
# Node ID: e63ec3be-4997-460f-b4e0-b99323c1a59b
# Text: 迷人的古代，动乱的近代，在不可阻挡地远去，对西班牙来说，它的标志就是殖民地在纷纷独立。西班牙还沉浸在一百年前的迷梦中，遥望美洲，
# 总觉得“海上无敌”，似霸主余威尚在，而美国，一定还只是个乡巴佬的国家。  可是，一场发生在古巴的美西战争，使得西班牙彻底惊醒。
# Score:  0.844
#
# Node ID: 016cad00-f379-420a-8477-eff8cedaf1ee
# Text: [image](./Images/133.jpeg)  内战前后，西班牙农民生活非常贫苦
# 至于宗教，不要说和“人”与生俱来，更何况这还是在西班牙。君不见，在西班牙历史上，有哪场战争能离得了宗教。
# 今天的西班牙，人们对天主教热情不减。  在巴塞罗那附近，仍然有几个规模很大的修道院。我们去了其中的蒙塞拉。山形奇特，如圣徒云集。到了修道院才
# 知道，这里的人们是把山峰看作圣徒化身，山峰一个一个，都有名有姓。  在南方的安达卢西亚，不论是塞维利亚，还是科尔多瓦，看着一个个教堂门口的公
# 告，几乎天天晚上轮着在游行。我们晚上回来，天黑了，街上却总是一片无头无尾的烛火的队伍，管乐在牵动人心。管乐队里，一定有几个十来岁的少年。人们
# 抬着装饰得美轮美奂的圣母塑像。每人手里一枝白色的蜡烛，粗粗长长的，卷着纸卷...
# Score:  0.843
#
# Node ID: 97cd06c6-c707-4d58-aecf-09067603be7e
# Text: 加泰罗尼亚，还有北方的巴斯克，是今天西班牙独立自主意识最强的地区。今天，这两个地区，又是西班牙最富庶的地方。  我们曾经爬到蒙特
# 惠奇后山，在那里鸟瞰巴塞罗那的海港，规模巨大，当然美极了。加泰罗尼亚不仅有巴塞罗那的海港、有工业，还有满山满坡满地的葡萄园。这里出产价廉物美
# 的葡萄酒。  在山居的几天里，主人曾带我们去看杰里达小镇。和西班牙所有的村镇一样，杰里达镇的中心是一个教堂，洁白的墙壁，高耸的钟塔，教堂前有
# 小小的广场，花坛。这是很普通的山区小镇景象。西班牙的这种小镇，不管穷富，都整洁到一尘不染的地步，在耀眼的阳光下，这整洁给人印象特别深刻。我们
# 读早期西欧人和美国人写的西班牙游记，都会提到这种整洁，都说西班牙人穷归穷，绝不肯显得猥琐窝囊。西班牙女人跪在地板上，把木头地板刷得条条木纹清
# 晰可见...
# Score:  0.838
#
# Node ID: 94196ab4-8b43-4a21-b16a-0fcb10d5288c
# Text: 旅人们到西班牙，首都马德里当是首选，这是西班牙在地理上和政治上的中心，历史积淀深厚，周边一圈都是历史古城。可是，很多旅人到西班牙
# 的第一站，选的不是马德里而是巴塞罗那。巴塞罗那也是古城，它的优势是更接近欧洲。从法国过来，翻过比利牛斯山就是它了。而且它靠海，从这里南下，一
# 路是地中海的蓝色海水和洁白的沙滩。  巴塞罗那的朋友曾带我们去了附近的一个滨海小城西格斯（Sitges）。记得那天早上，我们在巴塞罗那市区游
# 览，主人说要带我们去当地的饭店吃午饭。在我的习惯中，十二点半吃午饭已算是晚的，可是这次将近两点还没有动静。我饿得开始抓着什么都吃。在我们认为
# 午饭肯定已经取消的时候，主人把我们带到巴塞罗那郊区的一个小镇，在那里我们美美地吃了一顿。这是我们第一次照西班牙吃法，在烤得微焦喷香的面包上用
# 切开的...
# Score:  0.837
#
# Q: 对比马德里和巴塞罗那的游玩体验
# Generated 2 sub questions.
# [SpainTravelEssay] Q: What are the historical landmarks in Madrid and Barcelona?
# [SpainTravelEssay] Q: What are the cultural attractions in Madrid and Barcelona?
# [SpainTravelEssay] A: In Madrid, the historical landmarks include the Plaza Mayor and the old city area. In Barcelona, the Montjuic mountain is a significant historical landmark, known for hosting the 1929 World Exposition.
# [SpainTravelEssay] A: Madrid is known for its deep historical roots and surrounded by historical ancient cities, while Barcelona is closer to Europe and has a coastal location with the Mediterranean Sea and white sandy beaches. Additionally, Barcelona hosted the 1929 World Expo on Montjuic mountain, offering stunning views of the Barcelona harbor and the Mediterranean Sea.
# response Madrid offers a deep historical experience with landmarks such as Plaza Mayor and the old city area, while Barcelona provides a coastal experience with its proximity to the Mediterranean Sea and white sandy beaches. Additionally, Barcelona's Montjuic mountain offers stunning views of the harbor and the Mediterranean Sea.
# Node ID: 08bcb363-fd5c-4153-9a50-74b619ef29a2
# Text: Sub question: What are the historical landmarks in Madrid and
# Barcelona? Response: In Madrid, the historical landmarks include the
# Plaza Mayor and the old city area. In Barcelona, the Montjuic mountain
# is a significant historical landmark, known for hosting the 1929 World
# Exposition.
# Score: None
#
# Node ID: b54c72b6-711c-4d20-bb32-0d8a3e29fbc8
# Text: Sub question: What are the cultural attractions in Madrid and
# Barcelona? Response: Madrid is known for its deep historical roots and
# surrounded by historical ancient cities, while Barcelona is closer to
# Europe and has a coastal location with the Mediterranean Sea and white
# sandy beaches. Additionally, Barcelona hosted the 1929 World Expo on
# Mont...
# Score: None
#
# Node ID: 8b12c207-b98b-425e-a4bc-e19fc6bdd1c6
# Text: ![image](../Images/111.jpeg)  在街头描画菜单的西班牙老人  马约尔广场和老市政广场所在的这一片，就
# 是这个城市的老城区。可惜我们没有时间能像在巴塞罗那一样，好好在马德里的老城区逛逛。在马德里扩建的新城区，也有一些很好玩的地方。例如塞万提斯的
# 纪念碑。  在十六七世纪的风云跌宕起伏中，难得有一个平民，活得像塞万提斯那样，堪称是整整一本西班牙的二百年传奇。他在西班牙游历过，也阅读过和
# 思想过；他高谈阔论，又出国打仗，着实冲锋陷阵、流血受伤，受到皇家嘉奖；他当过海盗的人质奴隶，又逃跑被抓，差点上绞架在海外死个不明不白；等他终
# 于回到故乡，必须吃吃力力地谋生，却又蒙冤入狱。最后重病一场，死在家中。甚至没有人知道他的长相。可是他用笔塑造的两个人物，却永久地站在马德里的
# 市中心...
# Score:  0.845
#
# Node ID: d7d9ef86-485f-45b4-b11a-d1b46dc85e5f
# Text: 几乎在佛朗哥1975年年底去世的瞬间，人们就知道了，西班牙将要迅速变革。于是，我们仍然想知道，在佛朗哥统治时期，究竟为这样的变革
# ，做了一些什么准备。将近半个世纪西班牙人是怎么走过来的。他们后来的政治改革相对顺利，恐怕不能说和前面的路程毫无关系。  在巴塞罗那，我一直很
# 喜欢世界博览会的那一片叫做蒙特惠奇山（Montjuic）的地方。那是巴塞罗那市里的一座山，在此曾经举办了1929年世界博览会，可以居高临下俯
# 视巴塞罗那海港和蓝得叫人晕眩的地中海。那里唯一煞风景的是：为制造卖点，巴塞罗那人建造了一个虚假的西班牙“村庄”（Pole
# Espanyol），卖着很贵的门票，里面是很拙劣的假货。只要不进这个“假村庄”，蒙特惠奇绝对是一个很值得去的地方。
# ![image](../Images/194....
# Score:  0.842
#
# Node ID: 94196ab4-8b43-4a21-b16a-0fcb10d5288c
# Text: 旅人们到西班牙，首都马德里当是首选，这是西班牙在地理上和政治上的中心，历史积淀深厚，周边一圈都是历史古城。可是，很多旅人到西班牙
# 的第一站，选的不是马德里而是巴塞罗那。巴塞罗那也是古城，它的优势是更接近欧洲。从法国过来，翻过比利牛斯山就是它了。而且它靠海，从这里南下，一
# 路是地中海的蓝色海水和洁白的沙滩。  巴塞罗那的朋友曾带我们去了附近的一个滨海小城西格斯（Sitges）。记得那天早上，我们在巴塞罗那市区游
# 览，主人说要带我们去当地的饭店吃午饭。在我的习惯中，十二点半吃午饭已算是晚的，可是这次将近两点还没有动静。我饿得开始抓着什么都吃。在我们认为
# 午饭肯定已经取消的时候，主人把我们带到巴塞罗那郊区的一个小镇，在那里我们美美地吃了一顿。这是我们第一次照西班牙吃法，在烤得微焦喷香的面包上用
# 切开的...
# Score:  0.832
#
# Node ID: d7d9ef86-485f-45b4-b11a-d1b46dc85e5f
# Text: 几乎在佛朗哥1975年年底去世的瞬间，人们就知道了，西班牙将要迅速变革。于是，我们仍然想知道，在佛朗哥统治时期，究竟为这样的变革
# ，做了一些什么准备。将近半个世纪西班牙人是怎么走过来的。他们后来的政治改革相对顺利，恐怕不能说和前面的路程毫无关系。  在巴塞罗那，我一直很
# 喜欢世界博览会的那一片叫做蒙特惠奇山（Montjuic）的地方。那是巴塞罗那市里的一座山，在此曾经举办了1929年世界博览会，可以居高临下俯
# 视巴塞罗那海港和蓝得叫人晕眩的地中海。那里唯一煞风景的是：为制造卖点，巴塞罗那人建造了一个虚假的西班牙“村庄”（Pole
# Espanyol），卖着很贵的门票，里面是很拙劣的假货。只要不进这个“假村庄”，蒙特惠奇绝对是一个很值得去的地方。
# ![image](../Images/194....
# Score:  0.832

# %% [markdown]
# # DEFAULT_OPENAI_SUB_QUESTION_PROMPT_TMPL
#
# You are a world class state of the art agent.
#
# You have access to multiple tools, each representing a different data source or API.
# Each of the tools has a name and a description, formatted as a JSON dictionary.
# The keys of the dictionary are the names of the tools and the values are the \
# descriptions.
# Your purpose is to help answer a complex user question by generating a list of sub \
# questions that can be answered by the tools.
#
# These are the guidelines you consider when completing your task:
# * Be as specific as possible
# * The sub questions should be relevant to the user question
# * The sub questions should be answerable by the tools provided
# * You can generate multiple sub questions for each tool
# * Tools must be specified by their name, not their description
# * You don't need to use a tool if you don't think it's relevant
#
# Output the list of sub questions by calling the SubQuestionList function.
#
# ## Tools
# ```json
# {tools_str}
# ```
#
# ## User Question
# {query_str}

# %%
from llama_index.core.indices.query.query_transform import HyDEQueryTransform
from llama_index.core.query_engine import TransformQueryEngine
hyde = HyDEQueryTransform(include_original=True)
hyde_query_engine = TransformQueryEngine(index.as_query_engine(), hyde)

# %%
for q in question_list:
    print(f"{bcolors.BOLD}{bcolors.HEADER}Q: {q}{bcolors.ENDC}")
    response = hyde_query_engine.query(q)
    query_bundle = hyde(q)
    hyde_doc = query_bundle.embedding_strs[0]
    print(f"{bcolors.BOLD}Hypothetical Doc{bcolors.ENDC}")
    print(hyde_doc)
    print(f"{bcolors.BOLD}Result{bcolors.ENDC}")
    print(response)
    for node in response.source_nodes:
        print(node)
# Out:
# Q: 在巴塞罗那可以体验哪些有趣的事情
# Hypothetical Doc
# 在巴塞罗那，你可以体验许多有趣的事情。你可以参观圣家堂，这是安东尼奥·高迪的杰作，是一座令人惊叹的哥特式建筑。此外，你还可以漫步在兰布拉斯大道上，欣赏街头艺人的表演和购物。如果你喜欢艺术，那么高迪的其他作品，如巴特罗之家和米拉之家也是值得一游的地方。此外，你还可以品尝正宗的西班牙美食，如帕埃利亚和塔帕斯。最后，不要忘记在巴塞罗那海滩上放松身心，享受地中海的阳光和海风。总之，在巴塞罗那有太多有趣的事情等待着你去体验。
# Result
# You can experience the local dining culture by trying traditional Spanish dishes, such as bread with garlic, olive oil, and tomatoes. Exploring the old city area, including the Gothic Quarter near the cathedral, can provide a glimpse into the historical and cultural aspects of Barcelona. Additionally, staying in a youth hostel can offer a budget-friendly and communal travel experience.
# Node ID: 94196ab4-8b43-4a21-b16a-0fcb10d5288c
# Text: 旅人们到西班牙，首都马德里当是首选，这是西班牙在地理上和政治上的中心，历史积淀深厚，周边一圈都是历史古城。可是，很多旅人到西班牙
# 的第一站，选的不是马德里而是巴塞罗那。巴塞罗那也是古城，它的优势是更接近欧洲。从法国过来，翻过比利牛斯山就是它了。而且它靠海，从这里南下，一
# 路是地中海的蓝色海水和洁白的沙滩。  巴塞罗那的朋友曾带我们去了附近的一个滨海小城西格斯（Sitges）。记得那天早上，我们在巴塞罗那市区游
# 览，主人说要带我们去当地的饭店吃午饭。在我的习惯中，十二点半吃午饭已算是晚的，可是这次将近两点还没有动静。我饿得开始抓着什么都吃。在我们认为
# 午饭肯定已经取消的时候，主人把我们带到巴塞罗那郊区的一个小镇，在那里我们美美地吃了一顿。这是我们第一次照西班牙吃法，在烤得微焦喷香的面包上用
# 切开的...
# Score:  0.907
#
# Node ID: fddc9a87-9996-4b99-9f2d-383763b19552
# Text: 花一天青年旅舍的钱，在这里可以住三天。但我们在巴塞罗那错失的青年旅舍的经验，终于后来在塞维利亚补上了。青年旅舍现在有统间，也有双
# 人单间，可以在网上预订，也可以电话预订。它遍布世界，实在是很方便穷旅人。有关青年旅舍，还有一个朋友的经验是，她遇到过陌生男女同住的大统间。一
# 开始真是吓了一跳。  转到那个不留心去记住、下次就要找不到的小街，顿时感觉很歉疚，相信找到这个地方，真是花费了朋友很多精力。那是巴塞罗那主教
# 堂附近的哥特区，拉布拉斯大道边上，是老城的小巷。对旅游者来说，位置极好。你因此可以在老城区逗留得很晚，回住处很方便。  那是真正的老巴塞罗那
# 。可是，有了这次的经验，才知道那一片已经变成穷人聚集的地方。其实，这和所有的大都市是一样的。纽约、巴黎也有大片如此的老城区。那都是旧房，至少
# 有上几...
# Score:  0.899
#
# Q: 阿尔罕宫的有趣历史故事
# Hypothetical Doc
# 阿尔罕宫是一座位于西班牙格拉纳达的宫殿，它有着许多有趣的历史故事。据说，这座宫殿最初是一座阿拉伯王宫，建于13世纪。在15世纪，西班牙基督教征服者夺取了这座宫殿，并将其改建为一座基督教宫殿。在这个过程中，许多阿拉伯式的装饰和建筑被保留了下来，使得宫殿成为了阿拉伯和基督教文化的融合之地。
#
# 在宫殿内部，游客可以看到许多精美的阿拉伯式花纹和装饰，以及华丽的庭院和喷泉。其中最著名的是“狮子庭院”，庭院中心有一个大理石喷泉，四周是雕刻精美的狮子雕像，非常壮观。
#
# 此外，阿尔罕宫还有一个神秘的地下通道系统，据说曾经是皇宫内部的秘密通道，用于皇室成员的安全逃生。这些地下通道至今仍然是一个谜，吸引着许多游客前来探寻。
#
# 总的来说，阿尔罕宫不仅是一座美丽的宫殿，更是一个充满着神秘和历史的地方，吸引着世界各地的游客前来探索和品味。
# Result
# The history of the Alhambra Palace is filled with intriguing tales of opulence, power, and secrecy. It is a place where the grandeur of the palace, the lavish decorations, and the sheer scale of the residence reflect the wealth and influence of its inhabitants. The stories of the construction, the luxurious design, and the daily life within the palace create a captivating narrative that continues to fascinate visitors and historians alike.
# Node ID: d71f66b9-f0aa-439d-b654-5dd5786a5bda
# Text: [image](../Images/090.jpeg)  宫内庭院的喷泉  我们于耀眼的阳光下在宫里慢慢游荡，身边都是各色现代游
# 客。我们为异域文化发出惊喜的赞叹，却没有欧文的幸运。在傍晚，他孤身一人，一次次游荡在阿尔汉布拉宫的狮子厅。我们甚至没有能够进入狮子厅，这个阿
# 尔汉布拉宫最著名的庭院刚好不开放。我不知这是福还是憾。也许，上帝有意留给我们这样一个想象的空间？  狮子厅是需要想象力的。  狮子厅的故事，
# 被格拉那达人一代代地口传下来，添油加醋，细节也必然走样，不仅因为年代的久远，更因为它本来就是一段当事者要掩盖和避讳的历史。它太血腥。这几乎是
# 一个规律，凡是制造了血腥事件的人，总是想掩盖的。因为冥冥之中，总有一双眼睛，在闪闪发亮地直视着血案的制造者，让他坐卧不宁。
# ![image](....
# Score:  0.923
#
# Node ID: a0387e54-ddd6-4076-9856-28410c05f735
# Text: 这就是所谓的“阿尔扎哈拉”。也有历史学家认为，拉赫曼三世建造这座建筑物的真正原因，是由于他刚刚自封为哈里发，唯有一座精美的皇宫，
# 才能让拉赫曼三世真正感觉到他作为哈里发的尊严。  ![image](../Images/040.jpeg)  废墟  在这二十六年里，根据历
# 史记载，每天有六千块雕琢方正的石头投入使用。有四千根大理石柱和玛瑙柱是从罗马、伽太基、拜占庭，甚至是从法兰克国家运来。有一万五千座门被敷上了
# 铜箔。哈里发的殿堂有十六道大门，每边八道，都用镶嵌着乌木、象牙和宝石的拱形门框，拱框又有透明的水晶柱支撑。在一些记载中说，大殿中央有一个水银
# 喷泉，另一些记载说是水银池塘。总之，设计和装潢都极尽豪华奢侈。
# 这座宫殿成为世界上最豪华的住所。有大约两万五千人生活其中。其中一万三千男仆，六千...
# Score:  0.915
#
# Q: 塞维利亚有哪些美食
# Hypothetical Doc
# 塞维利亚是西班牙南部的一个美丽城市，以其丰富的美食文化而闻名。在塞维利亚，你可以品尝到各种美味佳肴，其中包括传统的西班牙火腿，如伊比利亚火腿和西班牙奶酪。此外，塞维利亚还以其海鲜菜肴而闻名，例如烤鳕鱼和炸鱿鱼圈。如果你喜欢甜食，那么塞维利亚的甜点也绝对不容错过，比如招牌甜点“塞维利亚甜橙酒”和“塞维利亚甜点”。此外，塞维利亚还有许多传统的小吃店和酒吧，供应各种美味的tapas，如西班牙土豆饼和炸鱿鱼圈。总的来说，塞维利亚的美食文化丰富多样，无论你喜欢肉类、海鲜还是甜点，都能在这里找到满足。
# Result
# 塞维利亚以其美味的美食而闻名，其中包括传统的塞维利亚火腿（Jamon de Sevilla）、塞维利亚橄榄（Aceitunas de Sevilla）和塞维利亚甜点特色如塞维利亚甜橙蛋糕（Torta de naranja de Sevilla）等。
# Node ID: 05dc4f72-b196-4cf9-958b-ca2fedc961ca
# Text: 虽然也文化繁荣，可塞维利亚一向更多是一个商业城市。这个时候，它开始了一个新的文化盛期。不过，它也自封了一个哈里发，已经独立了。
# 谁都会喜欢塞维利亚。它的位置在科尔多瓦的西南方一百公里左右。那是一个长着棕榈树、有着热带风情的城市。主教堂的外围有一个小广场。中间，走上一级
# 大方石砌筑的台阶，是一个巴洛克风格的喷泉。它和四周的建筑非常协调，四个巨大的狮子头，在噗噗地小心喷出水来，给人们带来一丝凉意。尤其在太阳下山
# 前，周围高大的建筑物刚刚在喷泉周围投下阴影，人们立即在喷泉水池的边缘坐上了一圈。哪怕是靠近一点水，都是好的。这时，想起一个朋友常说的话，“有
# 水，就活了”。
# 附近还有个用低矮的冬青围起来的小空间，放了一些坐椅。在黄昏，是老年人喜欢来坐坐的地方。塞维利亚是我们从巴塞罗那再次南下的第一站...
# Score:  0.897
#
# Node ID: 94196ab4-8b43-4a21-b16a-0fcb10d5288c
# Text: 旅人们到西班牙，首都马德里当是首选，这是西班牙在地理上和政治上的中心，历史积淀深厚，周边一圈都是历史古城。可是，很多旅人到西班牙
# 的第一站，选的不是马德里而是巴塞罗那。巴塞罗那也是古城，它的优势是更接近欧洲。从法国过来，翻过比利牛斯山就是它了。而且它靠海，从这里南下，一
# 路是地中海的蓝色海水和洁白的沙滩。  巴塞罗那的朋友曾带我们去了附近的一个滨海小城西格斯（Sitges）。记得那天早上，我们在巴塞罗那市区游
# 览，主人说要带我们去当地的饭店吃午饭。在我的习惯中，十二点半吃午饭已算是晚的，可是这次将近两点还没有动静。我饿得开始抓着什么都吃。在我们认为
# 午饭肯定已经取消的时候，主人把我们带到巴塞罗那郊区的一个小镇，在那里我们美美地吃了一顿。这是我们第一次照西班牙吃法，在烤得微焦喷香的面包上用
# 切开的...
# Score:  0.890
#
# Q: 如何准备一次西班牙旅行
# Hypothetical Doc
# 准备一次西班牙旅行需要一些计划和准备工作。首先，你需要确定你的旅行日期和目的地。西班牙有许多美丽的城市和景点，比如巴塞罗那、马德里、格拉纳达和塞维利亚等，你可以根据自己的兴趣选择合适的目的地。
#
# 其次，你需要办理签证和机票。如果你是中国公民，前往西班牙旅行需要办理申根签证，所以提前准备好所需的材料并提前预约签证中心。同时，你需要提前订购机票，以获得更好的价格和航班选择。
#
# 在确定行程和机票后，你需要预订酒店。根据你的预算和喜好，你可以选择住在市中心的酒店或者是更具特色的民宿。提前预订可以确保你有一个舒适的住宿环境。
#
# 最后，你需要准备好旅行期间的必需品，比如护照、旅行保险、西班牙语翻译工具、充电器和适合当地天气的衣物等。此外，你还可以提前了解一些当地的风俗习惯和美食文化，以便更好地融入当地生活。
#
# 总之，准备一次西班牙旅行需要提前规划和准备，但一切努力都将会为你带来一次难忘的旅行体验。
# Result
# When preparing for a trip to Spain, it's important to consider the diverse cultural and historical attractions in different regions. Researching the local customs and dining habits can enhance the travel experience. Additionally, being prepared for potential language barriers and considering the availability of basic amenities, such as laundry facilities, can help ensure a smooth and enjoyable journey.
# Node ID: 94196ab4-8b43-4a21-b16a-0fcb10d5288c
# Text: 旅人们到西班牙，首都马德里当是首选，这是西班牙在地理上和政治上的中心，历史积淀深厚，周边一圈都是历史古城。可是，很多旅人到西班牙
# 的第一站，选的不是马德里而是巴塞罗那。巴塞罗那也是古城，它的优势是更接近欧洲。从法国过来，翻过比利牛斯山就是它了。而且它靠海，从这里南下，一
# 路是地中海的蓝色海水和洁白的沙滩。  巴塞罗那的朋友曾带我们去了附近的一个滨海小城西格斯（Sitges）。记得那天早上，我们在巴塞罗那市区游
# 览，主人说要带我们去当地的饭店吃午饭。在我的习惯中，十二点半吃午饭已算是晚的，可是这次将近两点还没有动静。我饿得开始抓着什么都吃。在我们认为
# 午饭肯定已经取消的时候，主人把我们带到巴塞罗那郊区的一个小镇，在那里我们美美地吃了一顿。这是我们第一次照西班牙吃法，在烤得微焦喷香的面包上用
# 切开的...
# Score:  0.894
#
# Node ID: 9c7d6682-d688-4056-a3a3-ba1674dc2996
# Text: 美国小旅馆也有它方便的地方，它有一些基本的简单功能，例如制冰机、投币洗衣机和烘干机。来西班牙之前，我就把洗衣服的事情想得太简单。
# 在这里，假如住的是小旅馆，那么一边旅行，一边还要操心用最原始的方法洗衣服和晾干衣服。对一个疲惫不堪走了一天的旅人，这也是个不小的负担。  在
# 科尔多瓦火车站下车，东南西北都不知道。在车站的旅游中心要了一张地图，还是不知道我们要去的老城区在什么方向。西班牙人对问路的特别热情耐心周到，
# 话语滔滔，问题是他们大多不说英语。我们的经验是找年轻一点的问，碰运气。这一次比较运气，碰到一个骑自行车旅行、来自说英语国家的旅人。他指点方向
# ，告诉我们老城不远，走去就可以。顶着大太阳，挑树荫下走了二十来分钟，最后在科尔多瓦美术学院旁边的小巷子里，找到了这样一家小旅馆，放下行装，先
# 在老城...
# Score:  0.888
#
# Q: 对比马德里和巴塞罗那的游玩体验
# Hypothetical Doc
# 马德里和巴塞罗那都是西班牙最受欢迎的旅游目的地之一，但它们的游玩体验却有很大的不同。马德里是西班牙的首都，拥有丰富的历史和文化遗产。游客可以参观普拉多博物馆，品尝正宗的西班牙火腿和tapas，以及欣赏皇宫和西班牙广场等著名景点。马德里的气氛充满活力，夜生活丰富多彩，适合喜欢热闹的游客。
#
# 而巴塞罗那则是一座充满现代艺术和建筑的城市。游客可以参观高迪设计的圣家堂和巴特罗之家，欣赏地中海风情的海滩，以及在拉姆布拉斯大道上感受浓厚的艺术氛围。巴塞罗那也是足球迷的天堂，可以参观诺坎普球场和感受巴塞罗那足球俱乐部的狂热氛围。
#
# 总的来说，马德里更注重历史和文化，而巴塞罗那则更注重现代艺术和建筑。游客可以根据自己的兴趣和偏好选择适合自己的目的地，体验不同的西班牙风情。
# Result
# In comparing the experiences of visiting Madrid and Barcelona, one can find that Madrid is the geographical and political center of Spain with a deep historical background, while Barcelona is closer to Europe and has the advantage of being situated by the sea. Barcelona's old city is rich and vibrant, divided by the wide avenue of Las Ramblas, which is filled with shops, street vendors, and entertainers. The avenue leads to the Mediterranean Sea and features Columbus's golden statue. On the other hand, Madrid's attractions include historical sites and cultural landmarks, such as the Royal Palace and the Prado Museum. Both cities offer unique and diverse experiences for travelers.
# Node ID: 94196ab4-8b43-4a21-b16a-0fcb10d5288c
# Text: 旅人们到西班牙，首都马德里当是首选，这是西班牙在地理上和政治上的中心，历史积淀深厚，周边一圈都是历史古城。可是，很多旅人到西班牙
# 的第一站，选的不是马德里而是巴塞罗那。巴塞罗那也是古城，它的优势是更接近欧洲。从法国过来，翻过比利牛斯山就是它了。而且它靠海，从这里南下，一
# 路是地中海的蓝色海水和洁白的沙滩。  巴塞罗那的朋友曾带我们去了附近的一个滨海小城西格斯（Sitges）。记得那天早上，我们在巴塞罗那市区游
# 览，主人说要带我们去当地的饭店吃午饭。在我的习惯中，十二点半吃午饭已算是晚的，可是这次将近两点还没有动静。我饿得开始抓着什么都吃。在我们认为
# 午饭肯定已经取消的时候，主人把我们带到巴塞罗那郊区的一个小镇，在那里我们美美地吃了一顿。这是我们第一次照西班牙吃法，在烤得微焦喷香的面包上用
# 切开的...
# Score:  0.924
#
# Node ID: 7113f1e8-ec06-42bb-a1da-e66a98e3ee47
# Text: 我想，西班牙的命运是，欧洲还没有结束，非洲就已经开始。欧洲和非洲曾经长期僵持和拉锯，就对峙在西班牙的土地上。
# 可是在他们之前，先来的是罗马人。
# 这次我们来到巴塞罗那，时间显得从容，有三天，我们几乎一直转在老城里，漫无目的地游荡，绕着古罗马人修筑的城墙。
# 巴塞罗那的老城非常丰富。它被一条宽宽的大道，拉布拉斯大道（Las Ramblas）一分为二。后来才知道，西班牙的各大城市，差不多都有这样的大
# 道，它两边是商店，中间是宽宽的步行街。我们后来也在马德里的拉布拉斯大道上走过，可是都没有巴塞罗那这里好玩。这里热热闹闹，挤满了小摊贩、小酒铺
# 、小吃摊，当然，还有各路大显身手的艺人。最精彩的是，它结合了这一片起于罗马时代的老城。拉布拉斯大道的一端，抵达地中海海边的海港，一路走下去，
# 一直可以走到深...
# Score:  0.905
